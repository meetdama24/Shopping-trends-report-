# %% [markdown]
# <a href="https://colab.research.google.com/github/meetdama24/Shopping-trends-report-/blob/main/_%F0%9F%93%8A_Sales_Data_Analysis_Project_This_project_analyzes_restaurant_sales_data_using_Python_(Pandas%2C_Matplotlib%2C_Seaborn)_It_includes_data_cleaning%2C_visualization%2C_and_insights_generation_to_identify_trends_in_customer_tipping_behavior_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas matplotlib seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Retail Sales Dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

# Show first 5 rows
df.head()
# Shape of dataset
print("Rows & Columns:", df.shape)

# Data types
print("\nData Types:\n", df.dtypes)

# Summary statistics
print("\nSummary Statistics:\n", df.describe())

# Missing values
print("\nMissing Values:\n", df.isnull().sum())
# 1. Distribution of Total Bills
plt.figure(figsize=(8,5))
sns.histplot(df['total_bill'], bins=20, kde=True)
plt.title("Total Bill Distribution")
plt.show()

# 2. Average Tip by Day
plt.figure(figsize=(8,5))
sns.barplot(data=df, x="day", y="tip", estimator="mean")
plt.title("Average Tip by Day")
plt.show()

# 3. Total Bill vs Tip
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="total_bill", y="tip", hue="sex", size="size")
plt.title("Total Bill vs Tip")
plt.show()

# 4. Tips by Smoking Status
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x="smoker", y="tip")
plt.title("Tips by Smoker/Non-Smoker")
plt.show()
avg_tip = df['tip'].mean()
best_day = df.groupby('day')['tip'].mean().idxmax()
best_tip = df.groupby('day')['tip'].mean().max()

print("📊 Insights:")
print(f"- Average tip amount is ${avg_tip:.2f}.")
print(f"- Highest average tips are on {best_day} (${best_tip:.2f}).")
print("- Larger bills generally lead to larger tips.")
print("- Non-smokers tend to tip slightly more than smokers.")
# Out:
# ...
# Rows & Columns: (244, 7)
#
# Data Types:
#  total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object
#
# Summary Statistics:
#         total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
#
# Missing Values:
#  total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64
# 📊 Insights:
# - Average tip amount is $3.00.
# - Highest average tips are on Sun ($3.26).
# - Larger bills generally lead to larger tips.
# ...
